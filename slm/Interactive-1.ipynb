# %% [markdown]
# Connected to base (Python 3.10.14)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from data import MidiDataset
from train import EncoderOnlyModel
from util import preview_sm, sm_fix_overlap_notes, get_scale, loop_sm
import os
import IPython.display as ipd
from paper_checkpoints import checkpoints
from simplex_diffusion import SimplexDiffusionModel
import torch

device = "cuda:0"
ROOT_DIR = "../"

MODEL = "slm_drum"

OUTPUT_DIR = ROOT_DIR + "artefacts/examples_4"
TMP_DIR = ROOT_DIR + "artefacts/tmp"

os.makedirs(OUTPUT_DIR, exist_ok=True)

if MODEL == "slm":
    model = (
        EncoderOnlyModel.load_from_checkpoint(
            ROOT_DIR + checkpoints[MODEL],
            map_location=device,
        )
        .to(device)
        .eval()
    )
    generate = lambda mask: model.generate(mask, temperature=1.0, top_p=0.95)[0].argmax(
        axis=1
    )
elif MODEL == "slm_drum":
     model = (
        EncoderOnlyModel.load_from_checkpoint(
            ROOT_DIR + "checkpoints/ruby-surf-331/epoch=1119-step=17920-val/loss_epoch=0.03922.ckpt",
            map_location=device,
        )
        .to(device)
        .eval()
    )
    generate = lambda mask: model.generate(mask, temperature=1.0, top_p=0.95)[0].argmax(
        axis=1
    )

else:
    model = SimplexDiffusionModel.load_from_checkpoint(
        "../checkpoints/dark-sky-67/last.ckpt", map_location=device
    )
    # model = SimplexDiffusionModel.load_from_checkpoint(
    #     "../checkpoints/flowing-paper-64/last.ckpt", map_location=device
    # )

    generate = lambda x: model.sample2(
        mask,
        enforce_prior=True,
        nb_steps=100,
        top_p=0.99,
        batch_size=1,
        prior_strength=1,
        attribute_temperature={
            "pitch": 0.75,
            "onset/tick": 1.0,
            "onset/beat": 1.0,
            "velocity": 1.5,
        },
    )[0]


def preview(sm):
    sm = sm.copy()
    sm = sm_fix_overlap_notes(sm)
    preview_sm(loop_sm(sm, 4, 4))
    # add save button in ipython
    # if pressed a text box will appear to enter the name of the file
    # save the file in the output directory
# Out:
#   File <tokenize>:45
#     generate = lambda mask: model.generate(mask, temperature=1.0, top_p=0.95)[0].argmax(
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from data import MidiDataset
from train import EncoderOnlyModel
from util import preview_sm, sm_fix_overlap_notes, get_scale, loop_sm
import os
import IPython.display as ipd
from paper_checkpoints import checkpoints
from simplex_diffusion import SimplexDiffusionModel
import torch

device = "cuda:0"
ROOT_DIR = "../"

MODEL = "slm_drum"

OUTPUT_DIR = ROOT_DIR + "artefacts/examples_4"
TMP_DIR = ROOT_DIR + "artefacts/tmp"

os.makedirs(OUTPUT_DIR, exist_ok=True)

if MODEL == "slm":
    model = (
        EncoderOnlyModel.load_from_checkpoint(
            ROOT_DIR + checkpoints[MODEL],
            map_location=device,
        )
        .to(device)
        .eval()
    )
    generate = lambda mask: model.generate(mask, temperature=1.0, top_p=0.95)[0].argmax(
        axis=1
    )
elif MODEL == "slm_drum":
    model = (
        EncoderOnlyModel.load_from_checkpoint(
            ROOT_DIR + "checkpoints/ruby-surf-331/epoch=1119-step=17920-val/loss_epoch=0.03922.ckpt",
            map_location=device,
        )
        .to(device)
        .eval()
    )
    generate = lambda mask: model.generate(mask, temperature=1.0, top_p=0.95)[0].argmax(
        axis=1
    )

else:
    model = SimplexDiffusionModel.load_from_checkpoint(
        "../checkpoints/dark-sky-67/last.ckpt", map_location=device
    )
    # model = SimplexDiffusionModel.load_from_checkpoint(
    #     "../checkpoints/flowing-paper-64/last.ckpt", map_location=device
    # )

    generate = lambda x: model.sample2(
        mask,
        enforce_prior=True,
        nb_steps=100,
        top_p=0.99,
        batch_size=1,
        prior_strength=1,
        attribute_temperature={
            "pitch": 0.75,
            "onset/tick": 1.0,
            "onset/beat": 1.0,
            "velocity": 1.5,
        },
    )[0]


def preview(sm):
    sm = sm.copy()
    sm = sm_fix_overlap_notes(sm)
    preview_sm(loop_sm(sm, 4, 4))
    # add save button in ipython
    # if pressed a text box will appear to enter the name of the file
    # save the file in the output directory
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
# create 128 bpm rock loop with drums, bass, guitar with max 280 notes and minimum 2 drum notes and maximum 40 drum notes

ALL_INSTRUMENTS = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "instrument:" in token and token != "instrument:-"
}

ALL_TEMPOS = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "tempo:" in token and token != "tempo:-"
}
ALL_ONSET_BEATS = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "onset/beat:" in token and token != "onset/beat:-"
}
ALL_ONSET_TICKS = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "onset/tick:" in token and token != "onset/tick:-"
}
ALL_OFFSET_BEATS = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "offset/beat:" in token and token != "offset/beat:-"
}
ALL_OFFSET_TICKS = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "offset/tick:" in token and token != "offset/tick:-"
}
ALL_VELOCITIES = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "velocity:" in token and token != "velocity:-"
}
ALL_TAGS = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "tag:" in token and token != "tag:-"
}
ALL_PITCH = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "pitch:" in token and token != "pitch:-"
}
# all pitches that contain "(Drums)"
DRUM_PITCHES = {
    token.split(":")[-1]
    for token in model.tokenizer.vocab
    if "pitch:" in token and "(Drums)" in token
}

# create 128 bpm rock loop with drums, bass, guitar with max 280 notes
n_events = model.tokenizer.config["max_notes"]

def sm_to_events(x_sm):
    x = model.tokenizer.encode(x_sm, tag="other")
    tokens = model.tokenizer.indices_to_tokens(x)
    # group by n_attributes
    n_attributes = len(model.tokenizer.note_attribute_order)
    # n_events = model.tokenizer.config["max_notes"]
    events = []
    for i in range(0, len(tokens), n_attributes):
        event = {key: set() for key in model.tokenizer.note_attribute_order}
        for j in range(n_attributes):
            token = tokens[i + j]
            key, value = token.split(":")
            event[key].add(value)
        events.append(event)
    # create event objects
    events = [EventConstraint().intersect(event) for event in events]
    return events

class EventConstraint:
    def __init__(self):
        self.blank_event = {
            "instrument": ALL_INSTRUMENTS | {"-"},
            "pitch": ALL_PITCH | {"-"},
            "onset/beat": ALL_ONSET_BEATS | {"-"},
            "onset/tick": ALL_ONSET_TICKS | {"-"},
            "offset/beat": ALL_OFFSET_BEATS | {"-"},
            "offset/tick": ALL_OFFSET_TICKS | {"-"},
            "velocity": ALL_VELOCITIES | {"-"},
            "tag": ALL_TAGS | {"-"},
            "tempo": ALL_TEMPOS | {"-"},
        }

        self.a = self.blank_event.copy()

        self.all_active = {
            "instrument": ALL_INSTRUMENTS,
            "pitch": ALL_PITCH,
            "onset/beat": ALL_ONSET_BEATS,
            "onset/tick": ALL_ONSET_TICKS,
            "offset/beat": ALL_OFFSET_BEATS,
            "offset/tick": ALL_OFFSET_TICKS,
            "velocity": ALL_VELOCITIES,
            "tag": ALL_TAGS,
            "tempo": ALL_TEMPOS,
        }

        self.not_active = {
            "instrument": {"-"},
            "pitch": {"-"},
            "onset/beat": {"-"},
            "onset/tick": {"-"},
            "offset/beat": {"-"},
            "offset/tick": {"-"},
            "velocity": {"-"},
            "tag": {"-"},
            "tempo": {"-"},
        }
    
    def intersect(self,constraint):    
        for key in constraint:
            self.a[key] = self.a[key] & constraint[key]
        for key in self.a:
            assert  len(self.a[key])>0, f"Empty set for key {key}, constraint {constraint}, attributes {self.a}"
        return self
    
    def is_inactive(self):
        for key in self.a:
            if self.a[key] != {"-"}:
                return False
        return True

    def is_active(self):
        for key in self.a:
            if self.a[key] == {"-"}:
                return False
        return True
    
    def force_active(self):
        self.intersect(self.all_active)
        return self
    
    def force_inactive(self):
        self.intersect(self.not_active)
        return self
    
    def to_dict(self):
        return self.a

scale = get_scale("C pentatonic",range=(30, 100))

def scale_constraint(scale,pitch_range):
    scale_constraint = {
        "pitch": {str(note) for note in get_scale(scale, pitch_range)}
        | {"-"}
    }
    return scale_constraint

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    e += [
        EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
                                     }).force_active()
        for _ in range(30)
    ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Piano"},
    #             "pitch": scale_constraint("C major", (40, 100))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(30)
    # ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"pop","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 180/180 [00:02<00:00, 70.50it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section793 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section793 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section793 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section793 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section793 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section793 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section793 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section793 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section793 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section793 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section793 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section793&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section793 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    e += [
        EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
                                     }).force_active()
        for _ in range(30)
    ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Piano"},
    #             "pitch": scale_constraint("C major", (40, 100))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(30)
    # ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"funk","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 58
#      54     e = [ev.intersect({"tempo": {"138", "-"},"tag":{"funk","-"}}) for ev in e]
#      55     return e
# ---> 58 e = basic_arrangement()
#      61 mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
#      62 x = generate(mask)
#
# Cell In[6], line 54, in basic_arrangement()
#      52 e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
#      53 # set tempo and tag
# ---> 54 e = [ev.intersect({"tempo": {"138", "-"},"tag":{"funk","-"}}) for ev in e]
#      55 return e
#
# Cell In[6], line 54, in <listcomp>(.0)
#      52 e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
#      53 # set tempo and tag
# ---> 54 e = [ev.intersect({"tempo": {"138", "-"},"tag":{"funk","-"}}) for ev in e]
#      55 return e
#
# Cell In[4], line 122, in EventConstraint.intersect(self, constraint)
#     120     self.a[key] = self.a[key] & constraint[key]
#     121 for key in self.a:
# --> 122     assert  len(self.a[key])>0, f"Empty set for key {key}, constraint {constraint}, attributes {self.a}"
#     123 return self
#
# AssertionError: Empty set for key tag, constraint {'tempo': {'-', '138'}, 'tag': {'funk', '-'}}, attributes {'instrument': {'Drums'}, 'pitch': {'52 (Drums)', '60 (Drums)', '44 (Drums)', '65 (Drums)', '51 (Drums)', '70 (Drums)', '77 (Drums)', '58 (Drums)', '39 (Drums)', '54 (Drums)', '41 (Drums)', '71 (Drums)', '75 (Drums)', '76 (Drums)', '46 (Drums)', '55 (Drums)', '72 (Drums)', '68 (Drums)', '48 (Drums)', '74 (Drums)', '35 (Drums)', '36 (Drums)', '45 (Drums)', '78 (Drums)', '80 (Drums)', '53 (Drums)', '40 (Drums)', '43 (Drums)', '59 (Drums)', '49 (Drums)', '62 (Drums)', '42 (Drums)', '67 (Drums)', '38 (Drums)', '61 (Drums)', '47 (Drums)', '63 (Drums)', '57 (Drums)', '81 (Drums)', '73 (Drums)', '50 (Drums)', '37 (Drums)', '56 (Drums)', '79 (Drums)', '66 (Drums)', '69 (Drums)', '64 (Drums)'}, 'onset/beat': {'16', '9', '7', '3', '15', '11', '14', '2', '0', '5', '12', '13', '8', '4', '10', '1', '6'}, 'onset/tick': {'7', '0', '2', '4', '18', '6', '19', '16', '9', '3', '14', '22', '12', '13', '17', '15', '8', '1', '11', '20', '23', '5', '21', '10'}, 'offset/beat': {'16', '9', '7', '3', '15', '11', '14', '2', '0', '5', '12', '13', '8', '4', '10', 'none (Drums)', '1', '6'}, 'offset/tick': {'7', '0', '2', '4', '18', '6', '19', '16', '9', '3', '14', '22', '12', '13', 'none (Drums)', '17', '15', '8', '1', '11', '20', '23', '5', '21', '10'}, 'velocity': {'33', '0', '29', '103', '4', '58', '128', '45', '83', '12', '91', '120', '37', '95', '17', '54', '50', '111', '8', '41', '70', '99', '116', '25', '78', '124', '21', '66', '62', '87', '107', '74'}, 'tag': set(), 'tempo': {'138'}}

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(30)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"funk","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 58
#      54     e = [ev.intersect({"tempo": {"138", "-"},"tag":{"funk","-"}}) for ev in e]
#      55     return e
# ---> 58 e = basic_arrangement()
#      61 mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
#      62 x = generate(mask)
#
# Cell In[7], line 54, in basic_arrangement()
#      52 e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
#      53 # set tempo and tag
# ---> 54 e = [ev.intersect({"tempo": {"138", "-"},"tag":{"funk","-"}}) for ev in e]
#      55 return e
#
# Cell In[7], line 54, in <listcomp>(.0)
#      52 e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
#      53 # set tempo and tag
# ---> 54 e = [ev.intersect({"tempo": {"138", "-"},"tag":{"funk","-"}}) for ev in e]
#      55 return e
#
# Cell In[4], line 122, in EventConstraint.intersect(self, constraint)
#     120     self.a[key] = self.a[key] & constraint[key]
#     121 for key in self.a:
# --> 122     assert  len(self.a[key])>0, f"Empty set for key {key}, constraint {constraint}, attributes {self.a}"
#     123 return self
#
# AssertionError: Empty set for key tag, constraint {'tempo': {'-', '138'}, 'tag': {'funk', '-'}}, attributes {'instrument': {'Piano'}, 'pitch': {'93', '81', '48', '69', '65', '55', '60', '67', '79', '83', '91', '77', '59', '98', '95', '64', '89', '50', '71', '76', '52', '53', '72', '74', '88', '84', '57', '62', '86', '96'}, 'onset/beat': {'16', '9', '7', '3', '15', '11', '14', '2', '0', '5', '12', '13', '8', '4', '10', '1', '6'}, 'onset/tick': {'7', '0', '2', '4', '18', '6', '19', '16', '9', '3', '14', '22', '12', '13', '17', '15', '8', '1', '11', '20', '23', '5', '21', '10'}, 'offset/beat': {'16', '9', '7', '3', '15', '11', '14', '2', '0', '5', '12', '13', '8', '4', '10', 'none (Drums)', '1', '6'}, 'offset/tick': {'7', '0', '2', '4', '18', '6', '19', '16', '9', '3', '14', '22', '12', '13', 'none (Drums)', '17', '15', '8', '1', '11', '20', '23', '5', '21', '10'}, 'velocity': {'33', '0', '29', '103', '4', '58', '128', '45', '83', '12', '91', '120', '37', '95', '17', '54', '50', '111', '8', '41', '70', '99', '116', '25', '78', '124', '21', '66', '62', '87', '107', '74'}, 'tag': set(), 'tempo': {'138'}}

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(30)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"pop","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 180/180 [00:01<00:00, 113.69it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section420 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section420 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section420 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section420 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section420 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section420 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section420 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section420 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section420 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section420 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section420 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section420&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section420 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(30)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"pop","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 180/180 [00:01<00:00, 114.20it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section334 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section334 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section334 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section334 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section334 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section334 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section334 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section334 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section334 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section334 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section334 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section334&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section334 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(30)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"synth","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 180/180 [00:01<00:00, 110.97it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section297 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section297 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section297 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section297 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section297 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section297 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section297 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section297 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section297 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section297 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section297 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section297&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section297 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(30)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"synth","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 180/180 [00:01<00:00, 114.80it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section803 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section803 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section803 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section803 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section803 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section803 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section803 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section803 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section803 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section803 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section803 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section803&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section803 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"trance","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 125.39it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section928 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section928 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section928 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section928 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section928 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section928 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section928 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section928 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section928 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section928 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section928 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section928&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section928 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"trance","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 127.84it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section325 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section325 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section325 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section325 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section325 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section325 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section325 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section325 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section325 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section325 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section325 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section325&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section325 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"ambient","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 127.93it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section305 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section305 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section305 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section305 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section305 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section305 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section305 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section305 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section305 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section305 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section305 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section305&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section305 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"trap","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 125.99it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section139 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section139 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section139 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section139 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section139 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section139 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section139 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section139 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section139 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section139 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section139 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section139&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section139 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"trap","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 117.54it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section472 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section472 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section472 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section472 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section472 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section472 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section472 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section472 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section472 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section472 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section472 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section472&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section472 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"trap","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 136.22it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section89 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section89 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section89 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section89 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section89 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section89 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section89 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section89 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section89 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section89 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section89 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section89&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section89 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"trap","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 127.37it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section992 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section992 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section992 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section992 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section992 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section992 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section992 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section992 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section992 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section992 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section992 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section992&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section992 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"trap","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 115.97it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section458 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section458 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section458 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section458 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section458 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section458 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section458 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section458 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section458 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section458 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section458 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section458&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section458 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"chords","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 118.73it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section79 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section79 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section79 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section79 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section79 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section79 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section79 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section79 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section79 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section79 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section79 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section79&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section79 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"chords","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 126.16it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section324 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section324 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section324 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section324 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section324 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section324 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section324 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section324 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section324 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section324 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section324 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section324&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section324 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"chords","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 121.10it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section54 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section54 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section54 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section54 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section54 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section54 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section54 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section54 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section54 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section54 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section54 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section54&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section54 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"lofi","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 127.29it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section129 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section129 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section129 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section129 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section129 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section129 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section129 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section129 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section129 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section129 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section129 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section129&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section129 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"arpeggio","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 129.23it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section477 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section477 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section477 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section477 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section477 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section477 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section477 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section477 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section477 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section477 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section477 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section477&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section477 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"arpeggio","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 138.37it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section196 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section196 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section196 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section196 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section196 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section196 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section196 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section196 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section196 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section196 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section196 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section196&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section196 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"arpeggio","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 130.69it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section831 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section831 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section831 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section831 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section831 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section831 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section831 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section831 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section831 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section831 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section831 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section831&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section831 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                # "pitch": scale_constraint("C major", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"harp","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 136.31it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section253 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section253 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section253 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section253 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section253 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section253 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section253 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section253 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section253 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section253 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section253 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section253&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section253 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C pentatonic", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"harp","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 132.61it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section24 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section24 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section24 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section24 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section24 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section24 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section24 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section24 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section24 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section24 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section24 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section24&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section24 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C pentatonic", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"harp","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 129.85it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section738 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section738 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section738 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section738 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section738 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section738 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section738 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section738 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section738 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section738 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section738 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section738&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section738 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C pentatonic", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"harp","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 138.68it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section885 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section885 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section885 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section885 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section885 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section885 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section885 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section885 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section885 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section885 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section885 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section885&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section885 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C pentatonic", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"harp","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 117.48it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section179 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section179 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section179 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section179 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section179 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section179 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section179 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section179 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section179 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section179 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section179 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section179&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section179 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C pentatonic", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"harp","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 119.81it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section164 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section164 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section164 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section164 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section164 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section164 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section164 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section164 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section164 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section164 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section164 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section164&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section164 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>

# %%
# genre mix
def basic_arrangement():
    e = []
    # 10 forced drums
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "tag": {"jazz"}}).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced bass
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums"}, "pitch":DRUM_PITCHES
    #                                  }).force_active()
    #     for _ in range(30)
    # ]
    # 10 forced piano
    # e += [
    #     EventConstraint()
    #     .intersect(
    #         {
    #             "instrument": {"Bass"},
    #             "pitch": scale_constraint("C major", (30, 50))["pitch"],
    #         }
    #     )
    #     .force_active()
    #     for _ in range(10)
    # ]

    e += [
        EventConstraint()
        .intersect(
            {
                "instrument": {"Piano"},
                "pitch": scale_constraint("C pentatonic", (40, 100))["pitch"],
            }
        )
        .force_active()
        for _ in range(50)
    ]

    # # add bass pitch at 36
    # e += [
    #     EventConstraint().intersect({"instrument": {"Bass"}, "pitch": {"36"}, "onset/beat":{"0"}, "offset/beat":{"1","2","3"}}).force_active()
    # ]
    
    # # 150 optional drums, bass, guitar
    # e += [
    #     EventConstraint().intersect({"instrument": {"Drums","Bass","Piano","Guitar","-"}}) for _ in range(50)
    # ]

    e += [EventConstraint().force_inactive() for _ in range(n_events - len(e))]
    # set tempo and tag
    e = [ev.intersect({"tempo": {"138", "-"},"tag":{"harp","-"}}) for ev in e]
    return e


e = basic_arrangement()


mask = model.tokenizer.create_mask([ev.to_dict() for ev in e]).to(device)
x = generate(mask)
x_sm = model.tokenizer.decode(x)
preview(x_sm)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 125.02it/s]
# <iframe srcdoc="&lt;script src=&quot;https://cdn.jsdelivr.net/combine/npm/tone@14.7.58,npm/@magenta/music@1.23.1/es6/core.js,npm/focus-visible@5,npm/html-midi-player@1.5.0&quot;&gt;&lt;/script&gt;
# &lt;style&gt;
# /* Custom player style */
# #section986 midi-player {
#   display: block;
#   width: inherit;
#   margin: 4px;
#   margin-bottom: 0;
#   font-family: Arial;
# }
# p { margin:0 }
#
# #section986 midi-player::part(control-panel) {
#   background: #ff5;
#   border: 2px solid #000;
#   border-radius: 10px 10px 0 0;
# }
# #section986 midi-player::part(play-button) {
#   color: #353;
#   border: 2px solid currentColor;
#   background-color: #4d4;
#   border-radius: 20px;
#   transition: all 0.2s;
#   content: &#x27;hello&#x27;;
# }
# #section986 midi-player::part(play-button):hover {
#   color: #0a0;
#   background-color: #5f5;
#   border-radius: 10px;
# }
# #section986 midi-player::part(time) {
#   font-family: monospace;
# }
#
# /* Custom visualizer style */
# #section986 midi-visualizer .piano-roll-visualizer {
#   background: #ffd;
#   border: 2px solid black;
#   border-top: none;
#   border-radius: 0 0 10px 10px;
#   margin: 4px;
#   width: inherit;
#   margin-top: 0;
#   overflow: auto;
# }
# #section986 midi-visualizer svg rect.note {
#   opacity: 0.6;
#   stroke-width: 2;
# }
# #section986 midi-visualizer svg rect.note[data-instrument=&quot;0&quot;]{
#   fill: #e22;
#   stroke: #500;
# }
# #section986 midi-visualizer svg rect.note[data-instrument=&quot;2&quot;]{
#   fill: #2ee;
#   stroke: #055;
# }
# #section986 midi-visualizer svg rect.note[data-is-drum=&quot;true&quot;]{
#   fill: #888;
#   stroke: #888;
# }
# #section986 midi-visualizer svg rect.note.active {
#   opacity: 0.9;
#   stroke: #000;
#   stroke-width: 3;
# }
# &lt;/style&gt;
#
#           &lt;section id=&quot;section986&quot;&gt;&lt;p style=&quot;text-align:left;font-family:Arial;&quot;&gt;My Player&lt;span style=&quot;float:right;&quot;&gt;&lt;a href=&quot;data:audio/midi;base64,...&quot; target=&quot;_blank&quot;&gt;Download MIDI&lt;/a&gt;&lt;br&gt;&lt;/span&gt;&lt;/p&gt;
#           &lt;midi-player src=data:audio/midi;base64,... sound-font visualizer=&quot;#section986 midi-visualizer&quot;&gt;&lt;/midi-player&gt;
#           &lt;midi-visualizer src=data:audio/midi;base64,... type=piano-roll&gt;&lt;/midi-visualizer&gt;
#           &lt;/section&gt;
#           " width="100%" height="500"
#             style="border:none !important;"
#             "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen">'
#             </iframe>
